# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/Online Retail.xlsx', nrows = 50000,dtype = {'StockCode':str})
df
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 49995    540541     21332         MOROCCAN BEATEN METAL MIRROR         1
# 49996    540541     20831                     GOLD PHOTO FRAME         6
# 49997    540541     22169     FAMILY ALBUM WHITE PICTURE FRAME         2
# 49998    540541     22170   PICTURE FRAME WOOD TRIPLE PORTRAIT         4
# 49999    540541     22415                    WHITE TISSUE REAM         1
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #### bar chart top 10 quantity

# %%
fig = plt.figure()
ax = fig.add_subplot()
quantity = df['Description'].value_counts().head(10)
ax.bar(quantity.index,quantity.values)

ax.set_xlabel('Quantity')
ax.set_ylabel('InvoiceDate')
ax.set_title('Top 10 Quantity')
plt.xticks(rotation = 90)
plt.show()

# %%
quantity = df['Description'].value_counts().head(10).to_frame()
quantity
# Out:
#                                     count
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    289
# REGENCY CAKESTAND 3 TIER              226
# HAND WARMER BABUSHKA DESIGN           190
# PAPER CHAIN KIT 50'S CHRISTMAS        180
# SCOTTIE DOG HOT WATER BOTTLE          177
# HEART OF WICKER SMALL                 174
# CHOCOLATE HOT WATER BOTTLE            169
# JAM MAKING SET PRINTED                160
# JUMBO BAG RED RETROSPOT               153
# HOT WATER BOTTLE BABUSHKA             146

# %%
quantity.values
# Out:
# array([[289],
#        [226],
#        [190],
#        [180],
#        [177],
#        [174],
#        [169],
#        [160],
#        [153],
#        [146]])

# %%
quantity = df['UnitPrice'].groupby(df['StockCode']).sum()
quantity.sort_values(ascending=False).head(10)
# Out:
# StockCode
# AMAZONFEE       99667.47
# DOT             26619.96
# M                6526.85
# 22423            3155.25
# POST             1710.09
# 22655            1510.00
# 21258            1368.00
# BANK CHARGES     1077.30
# 22111            1009.21
# 22112            1008.55
# Name: UnitPrice, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_subplot()

quantity = df['UnitPrice'].groupby(df['StockCode']).sum()
top_10_quantity = quantity.sort_values(ascending=False).head(10)
ax.bar(top_10_quantity.index,top_10_quantity.values)

ax.set_xlabel('Stock')
ax.set_ylabel('Price')
ax.set_title('Top 10 Quantity')
plt.xticks(rotation = 90)
plt.show()

# %%
top_10_quantity.index
# Out:
# Index(['AMAZONFEE', 'DOT', 'M', '22423', 'POST', '22655', '21258',
#        'BANK CHARGES', '22111', '22112'],
#       dtype='object', name='StockCode')
